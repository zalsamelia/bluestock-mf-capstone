# %%
# ==========================================================
# Bluestock Mutual Fund Analytics
# Day 3 - Exploratory Data Analysis
# ==========================================================

# ==========================================================
# Import Libraries
# ==========================================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from pathlib import Path

# Display Options
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 150)
pd.set_option("display.max_colwidth", None)

print("=" * 60)
print("Libraries Successfully Imported")
print("=" * 60)

# ==========================================================
# Project Paths
# ==========================================================

PROJECT_ROOT = Path.cwd().parent

DATA_PATH = PROJECT_ROOT / "data" / "processed"

FIGURE_PATH = Path.cwd() / "figures"

FIGURE_PATH.mkdir(
    parents=True,
    exist_ok=True
)

print("=" * 60)
print("Project Paths")
print("=" * 60)

print(f"Project Root : {PROJECT_ROOT}")
print(f"Processed Data : {DATA_PATH}")
print(f"Figures Folder : {FIGURE_PATH}")

# ==========================================================
# Load Clean Datasets
# ==========================================================

fund_df = pd.read_csv(
    DATA_PATH / "clean_fund_master.csv",
    parse_dates=["launch_date"]
)

nav_df = pd.read_csv(
    DATA_PATH / "clean_nav_history.csv",
    parse_dates=["date"]
)

aum_df = pd.read_csv(
    DATA_PATH / "clean_aum_by_fund_house.csv",
    parse_dates=["date"]
)

sip_df = pd.read_csv(
    DATA_PATH / "clean_monthly_sip_inflows.csv",
    parse_dates=["month"]
)

category_df = pd.read_csv(
    DATA_PATH / "clean_category_inflows.csv",
    parse_dates=["month"]
)

folio_df = pd.read_csv(
    DATA_PATH / "clean_industry_folio_count.csv",
    parse_dates=["month"]
)

performance_df = pd.read_csv(
    DATA_PATH / "clean_scheme_performance.csv"
)

transaction_df = pd.read_csv(
    DATA_PATH / "clean_investor_transactions.csv",
    parse_dates=["transaction_date"]
)

portfolio_df = pd.read_csv(
    DATA_PATH / "clean_portfolio_holdings.csv",
    parse_dates=["portfolio_date"]
)

benchmark_df = pd.read_csv(
    DATA_PATH / "clean_benchmark_indices.csv",
    parse_dates=["date"]
)

print("=" * 60)
print("All datasets loaded successfully.")
print("=" * 60)

# ==========================================================
# Dataset Collection
# ==========================================================

datasets = {

    "Fund Master": fund_df,

    "NAV History": nav_df,

    "AUM by Fund House": aum_df,

    "Monthly SIP": sip_df,

    "Category Inflows": category_df,

    "Industry Folio": folio_df,

    "Scheme Performance": performance_df,

    "Investor Transactions": transaction_df,

    "Portfolio Holdings": portfolio_df,

    "Benchmark": benchmark_df

}

print("=" * 60)
print("Dataset Dictionary Created")
print("=" * 60)

print(f"Total Dataset : {len(datasets)}")

# ==========================================================
# Dataset Overview
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    print(f"Shape : {df.shape}")

    print("\nFirst Five Rows")

    display(df.head())

    # ==========================================================
# Dataset Dimensions
# ==========================================================

summary = []

for name, df in datasets.items():

    summary.append({

        "Dataset": name,

        "Rows": df.shape[0],

        "Columns": df.shape[1]

    })

summary_df = pd.DataFrame(summary)

summary_df

# ==========================================================
# Data Types
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    print(df.dtypes)

    # ==========================================================
# Dataset Information
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    df.info()

    print("\n")

    # ==========================================================
# Dataset Information
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    df.info()

    print("\n")

    # ==========================================================
# Dataset Size Comparison
# ==========================================================

plt.figure(figsize=(12,6))

plt.bar(

    summary_df["Dataset"],

    summary_df["Rows"]

)

plt.title("Number of Rows per Dataset")

plt.xlabel("Dataset")

plt.ylabel("Rows")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "dataset_size.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Missing Values
# ==========================================================

print("=" * 60)
print("Missing Value Assessment")
print("=" * 60)

missing_summary = []

for name, df in datasets.items():

    total_missing = df.isnull().sum().sum()

    missing_summary.append({

        "Dataset": name,

        "Missing Values": total_missing

    })

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    print(df.isnull().sum())

missing_df = pd.DataFrame(missing_summary)

print("\n")

print("=" * 60)

print("Overall Missing Value Summary")

print("=" * 60)

display(missing_df)

# ==========================================================
# Duplicate Records
# ==========================================================

print("=" * 60)
print("Duplicate Record Assessment")
print("=" * 60)

duplicate_summary = []

for name, df in datasets.items():

    duplicate_rows = df.duplicated().sum()

    duplicate_summary.append({

        "Dataset": name,

        "Duplicate Rows": duplicate_rows

    })

    print(f"{name} : {duplicate_rows}")

duplicate_df = pd.DataFrame(duplicate_summary)

print("\n")

display(duplicate_df)

# ==========================================================
# Unique Values
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    print(df.nunique())

    # ==========================================================
# Numeric Columns
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    numeric_columns = df.select_dtypes(include="number").columns

    print(list(numeric_columns))

    # ==========================================================
# Numeric Columns
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    numeric_columns = df.select_dtypes(include="number").columns

    print(list(numeric_columns))

    # ==========================================================
# Date Columns
# ==========================================================

for name, df in datasets.items():

    print("\n")

    print("=" * 60)

    print(name)

    print("=" * 60)

    date_columns = df.select_dtypes(include="datetime").columns

    print(list(date_columns))

    # ==========================================================
# Memory Usage
# ==========================================================

memory_summary = []

for name, df in datasets.items():

    memory_summary.append({

        "Dataset": name,

        "Memory (MB)": round(

            df.memory_usage(deep=True).sum() / 1024 / 1024,

            2

        )

    })

memory_df = pd.DataFrame(memory_summary)

display(memory_df)

# ==========================================================
# Missing Value Chart
# ==========================================================

plt.figure(figsize=(10,5))

plt.bar(

    missing_df["Dataset"],

    missing_df["Missing Values"]

)

plt.title("Missing Values by Dataset")

plt.xlabel("Dataset")

plt.ylabel("Missing Values")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "missing_values.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Duplicate Records Chart
# ==========================================================

plt.figure(figsize=(10,5))

plt.bar(

    duplicate_df["Dataset"],

    duplicate_df["Duplicate Rows"]

)

plt.title("Duplicate Records by Dataset")

plt.xlabel("Dataset")

plt.ylabel("Duplicate Rows")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "duplicate_records.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Memory Usage Chart
# ==========================================================

plt.figure(figsize=(10,5))

plt.bar(

    memory_df["Dataset"],

    memory_df["Memory (MB)"]

)

plt.title("Dataset Memory Usage")

plt.xlabel("Dataset")

plt.ylabel("Memory (MB)")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "memory_usage.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Data Quality Summary
# ==========================================================

print("=" * 60)
print("Data Quality Assessment Summary")
print("=" * 60)

print(f"Total Datasets : {len(datasets)}")

print(f"Total Missing Values : {missing_df['Missing Values'].sum()}")

print(f"Total Duplicate Rows : {duplicate_df['Duplicate Rows'].sum()}")

print("\nThe cleaned datasets show good overall data quality.")

print("Most datasets contain complete records with consistent")

print("data types and minimal quality issues.")

print("The datasets are suitable for exploratory data analysis.")

# ==========================================================
# FUND MASTER ANALYSIS
# ==========================================================

print("=" * 60)
print("FUND MASTER ANALYSIS")
print("=" * 60)

# ==========================================================
# Analysis 1
# Distribution of Mutual Fund Categories
# ==========================================================

print("\nDistribution of Mutual Fund Categories")

category_count = (
    fund_df["category"]
    .value_counts()
    .sort_values(ascending=False)
)

display(category_count)

plt.figure(figsize=(8,5))

plt.bar(
    category_count.index,
    category_count.values
)

plt.title("Distribution of Mutual Fund Categories")

plt.xlabel("Category")

plt.ylabel("Number of Funds")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "fund_category_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 2
# Top 5 Fund Houses
# ==========================================================

print("\nTop 5 Fund Houses")

top_fund_house = (
    fund_df["fund_house"]
    .value_counts()
    .head(5)
)

display(top_fund_house)

plt.figure(figsize=(8,5))

plt.bar(
    top_fund_house.index,
    top_fund_house.values
)

plt.title("Top 5 Fund Houses")

plt.xlabel("Fund House")

plt.ylabel("Number of Mutual Funds")

plt.xticks(rotation=20)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "top_5_fund_house.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 3
# Risk Category Distribution
# ==========================================================

print("\nRisk Category Distribution")

risk_distribution = (
    fund_df["risk_category"]
    .value_counts()
)

display(risk_distribution)

plt.figure(figsize=(8,5))

plt.bar(
    risk_distribution.index,
    risk_distribution.values
)

plt.title("Risk Category Distribution")

plt.xlabel("Risk Category")

plt.ylabel("Number of Funds")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "risk_category_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 4
# Launch Year Trend
# ==========================================================

print("\nLaunch Year Trend")

launch_year = (
    fund_df["launch_date"]
    .dt.year
    .value_counts()
    .sort_index()
)

display(launch_year)

plt.figure(figsize=(10,5))

plt.plot(
    launch_year.index,
    launch_year.values,
    marker="o"
)

plt.title("Mutual Fund Launch Trend")

plt.xlabel("Launch Year")

plt.ylabel("Number of Funds")

plt.grid(True)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "launch_year_trend.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 5
# Expense Ratio Distribution
# ==========================================================

print("\nExpense Ratio Distribution")

plt.figure(figsize=(8,5))

plt.hist(
    fund_df["expense_ratio_pct"],
    bins=10
)

plt.title("Expense Ratio Distribution")

plt.xlabel("Expense Ratio (%)")

plt.ylabel("Frequency")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "expense_ratio_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# PART 3B - NAV & PERFORMANCE ANALYSIS
# ==========================================================

print("=" * 60)
print("NAV & PERFORMANCE ANALYSIS")
print("=" * 60)

# ==========================================================
# Analysis 1
# NAV Distribution
# ==========================================================

print("\nNAV Distribution")

plt.figure(figsize=(8,5))

plt.hist(
    nav_df["nav"],
    bins=30
)

plt.title("Distribution of NAV")

plt.xlabel("NAV")

plt.ylabel("Frequency")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "nav_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 2
# Average NAV by Fund (Top 5)
# ==========================================================

print("\nTop 5 Average NAV")

average_nav = (

    nav_df

    .groupby("amfi_code")["nav"]

    .mean()

    .reset_index()

)

average_nav = average_nav.merge(

    fund_df[["amfi_code","scheme_name"]],

    on="amfi_code"

)

average_nav = average_nav.sort_values(

    by="nav",

    ascending=False

).head(5)

display(average_nav)

plt.figure(figsize=(10,5))

plt.bar(

    average_nav["scheme_name"],

    average_nav["nav"]

)

plt.xticks(rotation=20)

plt.title("Top 5 Average NAV")

plt.xlabel("Scheme")

plt.ylabel("Average NAV")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "top5_average_nav.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Analysis 3
# Average 3-Year Return (Top 5)
# ==========================================================

print("\nTop 5 Three-Year Return")

top_return = (

    performance_df

    .sort_values(

        by="return_3yr_pct",

        ascending=False

    )

    .head(5)

)

display(

    top_return[[

        "scheme_name",

        "return_3yr_pct"

    ]]

)

plt.figure(figsize=(10,5))

plt.bar(

    top_return["scheme_name"],

    top_return["return_3yr_pct"]

)

plt.xticks(rotation=20)

plt.title("Top 5 Three-Year Return")

plt.xlabel("Scheme")

plt.ylabel("Return (%)")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "top5_return.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Analysis 4
# Top 5 Sharpe Ratio
# ==========================================================

print("\nTop 5 Sharpe Ratio")

top_sharpe = (

    performance_df

    .sort_values(

        by="sharpe_ratio",

        ascending=False

    )

    .head(5)

)

display(

    top_sharpe[[

        "scheme_name",

        "sharpe_ratio"

    ]]

)

plt.figure(figsize=(10,5))

plt.bar(

    top_sharpe["scheme_name"],

    top_sharpe["sharpe_ratio"]

)

plt.xticks(rotation=20)

plt.title("Top 5 Sharpe Ratio")

plt.xlabel("Scheme")

plt.ylabel("Sharpe Ratio")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "top5_sharpe_ratio.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Analysis 5
# Top 5 AUM
# ==========================================================

print("\nTop 5 Assets Under Management")

top_aum = (

    performance_df

    .sort_values(

        by="aum_crore",

        ascending=False

    )

    .head(5)

)

display(

    top_aum[[

        "scheme_name",

        "aum_crore"

    ]]

)

plt.figure(figsize=(10,5))

plt.bar(

    top_aum["scheme_name"],

    top_aum["aum_crore"]

)

plt.xticks(rotation=20)

plt.title("Top 5 Assets Under Management")

plt.xlabel("Scheme")

plt.ylabel("AUM (Crore)")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "top5_aum.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
#  INVESTOR TRANSACTION ANALYSIS
# ==========================================================

print("=" * 60)
print("INVESTOR TRANSACTION ANALYSIS")
print("=" * 60)

# ==========================================================
# Analysis 1
# Transaction Type Distribution
# ==========================================================

print("\nTransaction Type Distribution")

transaction_type = (
    transaction_df["transaction_type"]
    .value_counts()
)

display(transaction_type)

plt.figure(figsize=(8,5))

plt.bar(
    transaction_type.index,
    transaction_type.values
)

plt.title("Transaction Type Distribution")

plt.xlabel("Transaction Type")

plt.ylabel("Number of Transactions")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "transaction_type_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 2
# Top 5 States
# ==========================================================

print("\nTop 5 States")

top_states = (
    transaction_df["state"]
    .value_counts()
    .head(5)
)

display(top_states)

plt.figure(figsize=(9,5))

plt.bar(
    top_states.index,
    top_states.values
)

plt.title("Top 5 States by Transactions")

plt.xlabel("State")

plt.ylabel("Transactions")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "top5_states.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 3
# Age Group Distribution
# ==========================================================

print("\nAge Group Distribution")

age_group = (
    transaction_df["age_group"]
    .value_counts()
)

display(age_group)

plt.figure(figsize=(8,5))

plt.bar(
    age_group.index,
    age_group.values
)

plt.title("Investor Age Group")

plt.xlabel("Age Group")

plt.ylabel("Number of Investors")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "age_group_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 4
# Payment Mode Distribution
# ==========================================================

print("\nPayment Mode Distribution")

payment = (
    transaction_df["payment_mode"]
    .value_counts()
)

display(payment)

plt.figure(figsize=(8,5))

plt.bar(
    payment.index,
    payment.values
)

plt.title("Payment Mode Distribution")

plt.xlabel("Payment Mode")

plt.ylabel("Transactions")

plt.xticks(rotation=20)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "payment_mode_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 5
# Average Investment by Age Group
# ==========================================================

print("\nAverage Investment by Age Group")

avg_investment = (
    transaction_df
    .groupby("age_group")["amount_inr"]
    .mean()
    .sort_values(ascending=False)
)

display(avg_investment)

plt.figure(figsize=(8,5))

plt.bar(
    avg_investment.index,
    avg_investment.values
)

plt.title("Average Investment by Age Group")

plt.xlabel("Age Group")

plt.ylabel("Average Investment (INR)")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "average_investment_age_group.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# INDUSTRY & MARKET ANALYSIS
# ==========================================================

print("=" * 60)
print("INDUSTRY & MARKET ANALYSIS")
print("=" * 60)

# ==========================================================
# Analysis 1
# AUM Trend
# ==========================================================

print("\nAUM Trend")

aum_trend = (
    aum_df
    .groupby("date")["aum_crore"]
    .sum()
    .reset_index()
)

display(aum_trend.head())

plt.figure(figsize=(10,5))

plt.plot(
    aum_trend["date"],
    aum_trend["aum_crore"],
    marker="o"
)

plt.title("Industry Assets Under Management Trend")

plt.xlabel("Date")

plt.ylabel("AUM (Crore)")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "aum_trend.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 2
# Monthly SIP Inflow Trend
# ==========================================================

print("\nMonthly SIP Inflow Trend")

display(sip_df.head())

plt.figure(figsize=(10,5))

plt.plot(
    sip_df["month"],
    sip_df["sip_inflow_crore"],
    marker="o"
)

plt.title("Monthly SIP Inflow")

plt.xlabel("Month")

plt.ylabel("SIP Inflow (Crore)")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "sip_inflow_trend.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 3
# Top 5 Categories by Net Inflow
# ==========================================================

print("\nTop 5 Categories by Net Inflow")

top_category = (
    category_df
    .groupby("category")["net_inflow_crore"]
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

display(top_category)

plt.figure(figsize=(9,5))

plt.bar(
    top_category.index,
    top_category.values
)

plt.title("Top 5 Categories by Net Inflow")

plt.xlabel("Category")

plt.ylabel("Net Inflow (Crore)")

plt.xticks(rotation=20)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "top5_category_inflow.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 4
# Total Folio Trend
# ==========================================================

print("\nTotal Folio Trend")

display(folio_df.head())

plt.figure(figsize=(10,5))

plt.plot(
    folio_df["month"],
    folio_df["total_folios_crore"],
    marker="o"
)

plt.title("Total Mutual Fund Folios")

plt.xlabel("Month")

plt.ylabel("Total Folios (Crore)")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "folio_trend.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Analysis 5
# Benchmark Index Trend
# ==========================================================

print("\nBenchmark Index Trend")

benchmark_trend = (
    benchmark_df
    .groupby("date")["close_value"]
    .mean()
    .reset_index()
)

display(benchmark_trend.head())

plt.figure(figsize=(10,5))

plt.plot(
    benchmark_trend["date"],
    benchmark_trend["close_value"]
)

plt.title("Average Benchmark Index Trend")

plt.xlabel("Date")

plt.ylabel("Average Close Value")

plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "benchmark_trend.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# ...
# Libraries Successfully Imported
# ...
# Project Paths
# ...
# Project Root : c:\Users\Zalsabilah.R.A.Arep\OneDrive\Documents\internship\bluestock-mf-capstone
# Processed Data : c:\Users\Zalsabilah.R.A.Arep\OneDrive\Documents\internship\bluestock-mf-capstone\data\processed
# Figures Folder : c:\Users\Zalsabilah.R.A.Arep\OneDrive\Documents\internship\bluestock-mf-capstone\analysis\figures
# ...
# All datasets loaded successfully.
# ...
# Dataset Dictionary Created
# ...
# Total Dataset : 10
#
#
# ...
# Fund Master
# ...
# Shape : (40, 15)
#
# First Five Rows
#    amfi_code       fund_house                                   scheme_name category sub_category     plan launch_date                  benchmark  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# ...

# %%
print("=" * 60)
print("PORTFOLIO DATA")
print("=" * 60)

display(portfolio_df.head())

print("\nColumns:")
print(portfolio_df.columns.tolist())

print("\nInfo:")
portfolio_df.info()

# ==========================================================
# PORTFOLIO ANALYSIS
# ==========================================================

print("=" * 60)
print("PORTFOLIO ANALYSIS")
print("=" * 60)

# ==========================================================
# Analysis 1
# Sector Allocation Donut Chart
# ==========================================================

print("\nSector Allocation")

sector_allocation = (
    portfolio_df
    .groupby("sector")["weight_pct"]
    .sum()
    .sort_values(ascending=False)
)

display(sector_allocation)

plt.figure(figsize=(8,8))

plt.pie(
    sector_allocation.values,
    labels=sector_allocation.index,
    autopct="%1.1f%%",
    startangle=90,
    wedgeprops={"width":0.4}
)

plt.title("Portfolio Sector Allocation")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "sector_allocation_donut.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# ...
# PORTFOLIO DATA
# ...
#    amfi_code stock_symbol                stock_name       sector  weight_pct  market_value_cr  current_price_inr portfolio_date
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85           737.09            6011.08     2025-12-31
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19            88.97            1074.65     2025-12-31
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90           208.45            5964.59     2025-12-31
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76           161.32            3748.82     2025-12-31
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25           725.90            1321.45     2025-12-31
# Columns:
# ['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight_pct', 'market_value_cr', 'current_price_inr', 'portfolio_date']
#
# Info:
# <class 'pandas.DataFrame'>
# ...

# %%
# ==========================================================
# NAV Dataset Overview
# ==========================================================

print(nav_df.head())

print("\nColumns:")
print(nav_df.columns.tolist())

print("\nDate Range:")
print(nav_df["date"].min())
print(nav_df["date"].max())

print("\nNumber of Funds:")
print(nav_df["amfi_code"].nunique())

# ==========================================================
# Merge NAV with Fund Names
# ==========================================================

nav_plot_df = nav_df.merge(
    fund_df[["amfi_code", "scheme_name"]],
    on="amfi_code",
    how="left"
)

display(nav_plot_df.head())

# ==========================================================
# NAV Trend Analysis (Interactive Plotly)
# ==========================================================

import plotly.express as px

fig = px.line(
    nav_plot_df,
    x="date",
    y="nav",
    color="scheme_name",
    title="Daily NAV Trend of Mutual Funds (2022–2026)"
)

# Highlight Bull Run 2023
fig.add_vrect(
    x0="2023-01-01",
    x1="2023-12-31",
    fillcolor="lightgreen",
    opacity=0.15,
    line_width=0,
    annotation_text="Bull Run",
    annotation_position="top left"
)

# Highlight Market Correction 2024
fig.add_vrect(
    x0="2024-01-01",
    x1="2024-12-31",
    fillcolor="lightcoral",
    opacity=0.15,
    line_width=0,
    annotation_text="Market Correction",
    annotation_position="top right"
)

fig.update_layout(

    xaxis_title="Date",

    yaxis_title="NAV",

    template="plotly_white",

    height=700,

    legend_title="Scheme"

)

fig.show()

fig.write_html(
    FIGURE_PATH / "nav_trend_interactive.html"
)

fig.write_image(
    FIGURE_PATH / "nav_trend_plotly.png",
    width=1600,
    height=900,
    scale=2
)
# Out:
#    amfi_code       date       nav
# 0     119551 2022-01-03  543856.0
# 1     119551 2022-01-04  543474.0
# 2     119551 2022-01-05  546869.0
# 3     119551 2022-01-06   55455.0
# 4     119551 2022-01-07  553692.0
#
# Columns:
# ['amfi_code', 'date', 'nav']
#
# Date Range:
# 2022-01-03 00:00:00
# 2026-05-29 00:00:00
#
# Number of Funds:
# 40
#    amfi_code       date       nav                                scheme_name
# 0     119551 2022-01-03  543856.0  SBI Bluechip Fund - Regular Plan - Growth
# 1     119551 2022-01-04  543474.0  SBI Bluechip Fund - Regular Plan - Growth
# 2     119551 2022-01-05  546869.0  SBI Bluechip Fund - Regular Plan - Growth
# 3     119551 2022-01-06   55455.0  SBI Bluechip Fund - Regular Plan - Growth
# 4     119551 2022-01-07  553692.0  SBI Bluechip Fund - Regular Plan - Growth

# %%
# ==========================================================
# AUM Growth by Fund House (2022–2025)
# ==========================================================

print("=" * 60)
print("AUM Growth by Fund House")
print("=" * 60)

# Tambahkan kolom tahun
aum_df["year"] = aum_df["date"].dt.year

# Ambil AUM terakhir setiap fund house di setiap tahun
aum_yearly = (
    aum_df
    .sort_values("date")
    .groupby(["fund_house", "year"], as_index=False)
    .last()
)

display(aum_yearly.head())

aum_growth = aum_yearly.pivot(
    index="fund_house",
    columns="year",
    values="aum_lakh_crore"
)

display(aum_growth)

# ==========================================================
# Grouped Bar Chart - AUM Growth by Fund House
# ==========================================================

plt.figure(figsize=(14,7))

ax = aum_growth.plot(
    kind="bar",
    figsize=(14,7)
)

plt.title("AUM Growth by Fund House (2022–2025)")

plt.xlabel("Fund House")

plt.ylabel("AUM (Lakh Crore)")

plt.xticks(rotation=45, ha="right")

plt.legend(title="Year")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "aum_growth_fund_house.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Highlight SBI Mutual Fund
# ==========================================================

plt.figure(figsize=(14,7))

ax = aum_growth.plot(
    kind="bar",
    figsize=(14,7)
)

# Warnai semua abu-abu
for container in ax.containers:
    for bar in container:
        bar.set_color("lightgray")

# Cari posisi SBI
fund_names = list(aum_growth.index)

if "SBI Mutual Fund" in fund_names:

    sbi_index = fund_names.index("SBI Mutual Fund")

    # Warnai semua bar SBI
    for container in ax.containers:
        container[sbi_index].set_color("royalblue")

    ax.annotate(
        "SBI Dominance\n~12.5 Lakh Cr",
        xy=(sbi_index, aum_growth.loc["SBI Mutual Fund"].max()),
        xytext=(sbi_index + 1, aum_growth.loc["SBI Mutual Fund"].max() + 1),
        arrowprops=dict(arrowstyle="->"),
        fontsize=10,
        color="red"
    )

plt.title("AUM Growth by Fund House (2022–2025)")

plt.xlabel("Fund House")

plt.ylabel("AUM (Lakh Crore)")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH / "aum_growth_highlight_sbi.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# ...
# AUM Growth by Fund House
# ...
#                  fund_house  year       date  aum_lakh_crore  aum_crore  num_schemes
# 0  Aditya Birla Sun Life MF  2022 2022-09-30            2.85     285000          199
# 1  Aditya Birla Sun Life MF  2023 2023-09-30            3.08     308000          199
# 2  Aditya Birla Sun Life MF  2024 2024-12-31            3.84     384000          199
# 3  Aditya Birla Sun Life MF  2025 2025-12-31            4.60     460000          199
# 4          Axis Mutual Fund  2022 2022-09-30            2.40     240000           95
# year                      2022  2023   2024   2025
# fund_house
# Aditya Birla Sun Life MF  2.85  3.08   3.84   4.60
# Axis Mutual Fund          2.40  2.60   3.00   3.50
# DSP Mutual Fund           1.12  1.32   1.88   2.30
# HDFC Mutual Fund          4.45  5.35   7.87   9.30
# ICICI Prudential MF       4.88  5.90   8.74  10.74
# Kotak Mahindra MF         2.72  3.25   4.89   5.80
# Mirae Asset MF            1.08  1.42   2.10   2.90
# ...

# %%
# ==========================================================
# Check Monthly SIP Dataset
# ==========================================================

display(sip_df.head())

print("\nColumns:")
print(sip_df.columns.tolist())

print("\nDate Range:")
print(sip_df["month"].min())
print(sip_df["month"].max())

print("\nNumber of Records:")
print(len(sip_df))

import plotly.express as px
# ==========================================================
# Monthly SIP Inflow Trend (2022–2025)
# ==========================================================

fig = px.line(
    sip_df,
    x="month",
    y="sip_inflow_crore",
    markers=True,
    title="Monthly SIP Inflow Trend (Jan 2022 – Dec 2025)"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="SIP Inflow (Crore INR)",
    template="plotly_white"
)

fig.show()

# Cari nilai SIP tertinggi
max_row = sip_df.loc[sip_df["sip_inflow_crore"].idxmax()]

fig = px.line(
    sip_df,
    x="month",
    y="sip_inflow_crore",
    markers=True,
    title="Monthly SIP Inflow Trend (Jan 2022 – Dec 2025)"
)

fig.add_annotation(
    x=max_row["month"],
    y=max_row["sip_inflow_crore"],
    text=f"All-Time High<br>{max_row['sip_inflow_crore']:,.0f} Cr",
    showarrow=True,
    arrowhead=2,
    yshift=25
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="SIP Inflow (Crore INR)",
    template="plotly_white"
)

fig.show()
fig.write_image(
    FIGURE_PATH / "sip_inflow_trend_plotly.png",
    width=1200,
    height=600
)
# Out:
#        month  sip_inflow_crore  active_sip_accounts_crore  new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0 2022-01-01             11517                       4.91                   9.10                4.80             NaN
# 1 2022-02-01             11438                       4.93                   8.20                4.85             NaN
# 2 2022-03-01             12328                       5.09                  10.50                5.01             NaN
# 3 2022-04-01             11863                       5.48                   9.52                5.12             NaN
# 4 2022-05-01             12286                       5.55                   8.10                5.15             NaN
# Columns:
# ['month', 'sip_inflow_crore', 'active_sip_accounts_crore', 'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct']
#
# Date Range:
# 2022-01-01 00:00:00
# 2025-12-01 00:00:00
#
# Number of Records:
# 48

# %%
# ==========================================================
# Category Inflow Heatmap
# ==========================================================

import seaborn as sns

category_heatmap = (
    category_df
    .pivot_table(
        index="category",
        columns="month",
        values="net_inflow_crore",
        aggfunc="sum"
    )
)

plt.figure(figsize=(14,6))

sns.heatmap(
    category_heatmap,
    cmap="YlGnBu",
    linewidths=.5
)

plt.title("Monthly Net Inflow by Category")

plt.xlabel("Month")

plt.ylabel("Fund Category")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH/"category_inflow_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
age = transaction_df["age_group"].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    age,
    labels=age.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Investor Age Group Distribution")

plt.savefig(
    FIGURE_PATH/"age_group_pie.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

gender = transaction_df["gender"].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    gender,
    labels=gender.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Gender Distribution")

plt.savefig(
    FIGURE_PATH/"gender_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

plt.figure(figsize=(9,5))

sns.boxplot(
    data=transaction_df,
    x="age_group",
    y="amount_inr"
)

plt.title("Investment Amount by Age Group")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH/"investment_boxplot_age.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
state_amount = (
    transaction_df
    .groupby("state")["amount_inr"]
    .sum()
    .sort_values()
)

plt.figure(figsize=(10,7))

plt.barh(
    state_amount.index,
    state_amount.values
)

plt.title("Total Investment Amount by State")

plt.xlabel("Investment (INR)")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH/"state_investment.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# ==========================================================
# Geographic Distribution
# Analysis 1
# SIP Amount by State
# ==========================================================

print("=" * 60)
print("SIP Amount by State")
print("=" * 60)

state_amount = (

    transaction_df

    .groupby("state")["amount_inr"]

    .sum()

    .sort_values(ascending=False)

)

display(state_amount)

plt.figure(figsize=(10,6))

plt.barh(

    state_amount.index,

    state_amount.values

)

plt.title("Total Investment Amount by State")

plt.xlabel("Investment Amount (INR)")

plt.ylabel("State")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "sip_amount_by_state.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()

# ==========================================================
# Analysis 2
# T30 vs B30 Distribution
# ==========================================================

print("=" * 60)
print("City Tier Distribution")
print("=" * 60)

city_tier = (

    transaction_df["city_tier"]

    .value_counts()

)

display(city_tier)

plt.figure(figsize=(6,6))

plt.pie(

    city_tier,

    labels=city_tier.index,

    autopct="%1.1f%%",

    startangle=90

)

plt.title("T30 vs B30 Investor Distribution")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "city_tier_distribution.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()
# Out:
# ...
# SIP Amount by State
# ...
# state
# Punjab            315780459
# Tamil Nadu        315177237
# Madhya Pradesh    308312493
# Rajasthan         298645822
# Gujarat           298358940
# West Bengal       297182514
# Telangana         290219284
# Delhi             289633404
# Uttar Pradesh     285368873
# Haryana           279634354
# Karnataka         273753570
# Maharashtra       269513480
# Name: amount_inr, dtype: int64
# ...
# City Tier Distribution
# ...
# city_tier
# T30    21719
# B30    11059
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))

plt.plot(
    folio_df["month"],
    folio_df["total_folios_crore"],
    marker="o"
)

plt.scatter(
    folio_df.iloc[0]["month"],
    folio_df.iloc[0]["total_folios_crore"],
    s=120
)

plt.scatter(
    folio_df.iloc[-1]["month"],
    folio_df.iloc[-1]["total_folios_crore"],
    s=120
)

plt.annotate(
    "13.26 Cr",
    (
        folio_df.iloc[0]["month"],
        folio_df.iloc[0]["total_folios_crore"]
    )
)

plt.annotate(
    "26.12 Cr",
    (
        folio_df.iloc[-1]["month"],
        folio_df.iloc[-1]["total_folios_crore"]
    )
)

plt.title("Industry Folio Growth")

plt.tight_layout()

plt.savefig(
    FIGURE_PATH/"folio_growth.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# ==========================================================
# NAV Return Correlation Matrix
# ==========================================================

print("=" * 60)
print("NAV Return Correlation Matrix")
print("=" * 60)

# Ambil 10 fund pertama
selected_funds = nav_df["amfi_code"].unique()[:10]

selected_nav = nav_df[
    nav_df["amfi_code"].isin(selected_funds)
].copy()

display(selected_nav.head())

nav_pivot = (

    selected_nav

    .pivot_table(

        index="date",

        columns="amfi_code",

        values="nav"

    )

)

display(nav_pivot.head())

daily_returns = nav_pivot.pct_change()

display(daily_returns.head())

correlation_matrix = daily_returns.corr()

display(correlation_matrix)

plt.figure(figsize=(10,8))

sns.heatmap(

    correlation_matrix,

    annot=True,

    cmap="coolwarm",

    linewidths=0.5,

    fmt=".2f"

)

plt.title("Daily NAV Return Correlation Matrix")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "nav_return_correlation_matrix.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()
# Out:
# ...
# NAV Return Correlation Matrix
# ...
#    amfi_code       date       nav
# 0     119551 2022-01-03  543856.0
# 1     119551 2022-01-04  543474.0
# 2     119551 2022-01-05  546869.0
# 3     119551 2022-01-06   55455.0
# 4     119551 2022-01-07  553692.0
# amfi_code      100016    100025      100033    119120    119551    119552    119598    119599     125497     125498
# date
# 2022-01-03  5204608.0  263169.0  1073758.00  421391.0  543856.0  584174.0  898738.0  964565.0  5601443.0  1175969.0
# 2022-01-04  5150971.0  262234.0  1059447.00  422508.0  543474.0   57348.0  885495.0  946512.0  5607052.0  1170077.0
# 2022-01-05  5217239.0  262221.0      105.48  424374.0  546869.0  570552.0  880925.0  945436.0  5630884.0  1164011.0
# 2022-01-06   515788.0  261728.0   104935.00  425901.0   55455.0  564224.0  885175.0  937944.0  5610675.0  1160861.0
# 2022-01-07  5151639.0  262261.0  1043318.00  424851.0  553692.0   57275.0  914235.0  896438.0   559542.0  1146164.0
# ...

# %%
# ==========================================================
# Portfolio Analysis
# ==========================================================

print("=" * 60)
print("PORTFOLIO ANALYSIS")
print("=" * 60)

sector_weight = (

    portfolio_df

    .groupby("sector")["weight_pct"]

    .sum()

    .sort_values(ascending=False)

)

display(sector_weight)

plt.figure(figsize=(8,8))

plt.pie(

    sector_weight,

    labels=sector_weight.index,

    autopct="%1.1f%%",

    startangle=90,

    wedgeprops={"width":0.4}

)

plt.title("Sector Allocation Across Equity Funds")

plt.tight_layout()

plt.savefig(

    FIGURE_PATH / "sector_allocation_donut.png",

    dpi=300,

    bbox_inches="tight"

)

plt.show()
# Out:
# ...
# PORTFOLIO ANALYSIS
# ...
# sector
# Banking           652.26
# IT                455.47
# Pharma            407.45
# Automobile        323.65
# Utilities         265.54
# FMCG              229.11
# Infrastructure    192.16
# Diversified       169.23
# Telecom           145.62
# Consumer Goods    127.61
# NBFC              119.09
# Energy            117.91
# Cement            105.03
# Paints             89.86
# Name: weight_pct, dtype: float64

# %% [markdown]
# # Key Exploratory Data Analysis (EDA) Findings
#
# This section summarizes the key insights obtained from the exploratory data analysis of the Bluestock Mutual Fund Analytics dataset. The findings are based on the visualizations and descriptive analysis performed throughout this notebook.
#
# ---
#
# ## 1. Mutual Fund Category Distribution
#
# The dataset shows that equity-oriented mutual funds represent the largest proportion of available investment schemes. This indicates that equity funds remain the most popular investment vehicle among asset management companies due to their long-term growth potential.
#
# **Supporting Chart:** `fund_category_distribution.png`
#
# ---
#
# ## 2. Market Concentration Among Fund Houses
#
# The mutual fund industry is concentrated among several large asset management companies. The top five fund houses manage a considerably higher number of schemes than smaller competitors, demonstrating their dominant position in the market.
#
# **Supporting Chart:** `top_5_fund_house.png`
#
# ---
#
# ## 3. Industry Assets Under Management Continue to Grow
#
# Assets Under Management (AUM) increased consistently between 2022 and 2025 across all major fund houses. SBI Mutual Fund maintained the largest AUM throughout the observation period, reflecting its strong market leadership.
#
# **Supporting Chart:** `aum_growth_bar.png`
#
# ---
#
# ## 4. Daily NAV Shows Long-Term Upward Movement
#
# The Net Asset Value (NAV) trend demonstrates an overall upward movement throughout the analysis period despite temporary market fluctuations. The visualization highlights periods of strong market performance as well as short-term corrections, illustrating the resilience of mutual fund investments over time.
#
# **Supporting Chart:** `nav_trend_plotly.png`
#
# ---
#
# ## 5. Monthly SIP Contributions Continue to Increase
#
# Monthly Systematic Investment Plan (SIP) inflows display a steady increasing trend from 2022 through 2025. The highest monthly inflow occurs in December 2025, indicating growing confidence and participation from retail investors in systematic investing.
#
# **Supporting Chart:** `sip_inflow_trend_plotly.png`
#
# ---
#
# ## 6. Banking Sector Dominates Equity Fund Portfolios
#
# Sector allocation analysis reveals that the Banking sector accounts for the largest cumulative portfolio weight among equity mutual funds. Information Technology and Pharmaceutical companies also represent significant portions of portfolio allocations, reflecting their importance within diversified investment portfolios.
#
# **Supporting Chart:** `sector_allocation_donut.png`
#
# ---
#
# ## 7. Investor Demographics Suggest Strong Participation from Working-Age Individuals
#
# Most investment activity originates from working-age investors. The distribution of investment amounts varies across different age groups, while gender participation appears relatively balanced, indicating broad investor participation across demographic segments.
#
# **Supporting Charts:**
# - `age_group_pie.png`
# - `gender_distribution.png`
# - `investment_boxplot_age.png`
#
# ---
#
# ## 8. Investment Activity is Concentrated in Major States and Tier-30 Cities
#
# Geographical analysis indicates that investment amounts are concentrated in several major states. Furthermore, Tier-30 cities contribute a larger proportion of investments than Beyond-30 (B30) locations, highlighting stronger mutual fund penetration in highly urbanized regions.
#
# **Supporting Charts:**
# - `sip_amount_by_state.png`
# - `city_tier_distribution.png`
#
# ---
#
# ## 9. Mutual Fund Folios Continue to Expand
#
# The total number of mutual fund folios increased substantially between 2022 and 2025, demonstrating continuous growth in investor participation. This trend suggests increasing public awareness and adoption of mutual fund investment products.
#
# **Supporting Chart:** `folio_growth.png`
#
# ---
#
# ## 10. Moderate Correlation Exists Across Selected Mutual Funds
#
# The daily return correlation matrix shows that most selected mutual funds exhibit positive but not perfect correlations. This suggests that diversification remains beneficial, as investing across multiple schemes may reduce portfolio risk while maintaining exposure to different market segments.
#
# **Supporting Chart:** `nav_return_correlation_matrix.png`
#
# ---
#
# # Overall Conclusion
#
# The exploratory data analysis indicates that the Indian mutual fund industry experienced sustained growth during the analysis period. Assets Under Management, SIP inflows, and investor folios all increased steadily, reflecting improving investor confidence and continued market expansion. Portfolio allocation remains heavily concentrated in Banking, Information Technology, and Pharmaceutical sectors, while geographic analysis shows that investments are primarily concentrated in major states and Tier-30 cities. Overall, the datasets demonstrate strong data quality and provide meaningful insights into fund performance, investor behaviour, portfolio composition, and industry growth, making them suitable for subsequent dashboard development and advanced analytical tasks.
